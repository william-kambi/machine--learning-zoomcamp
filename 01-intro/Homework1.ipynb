# %%
# Q1
import pandas as pd
import numpy as np

print("Pandas version:", pd.__version__)
# Out:
# Pandas version: 3.0.6

# %%
# loading the data
df = pd.read_csv("car_fuel_efficiency_2026.csv")
df.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# ...

# %%
# getting a grasp of the column names
df.columns
# Out:
# Index(['model_year', 'origin', 'fuel_type', 'drivetrain', 'num_doors',
#        'engine_displacement', 'num_cylinders', 'horsepower', 'vehicle_weight',
#        'acceleration', 'fuel_efficiency_mpg'],
#       dtype='str')

# %%
# Q2
print(len(df))
# Out:
# 10000

# %%
# Q3
print(len(df['fuel_type'].unique()))
# Out:
# 3

# %%
# Q4
print((df.isnull().sum() > 0).sum())
# Out:
# 2

# %%
# Q5
df[df["origin"] == "Asia"]["fuel_efficiency_mpg"].max().item()
# Out:
# 41.2

# %%
# Q6 i)median value
median_before = df["horsepower"].median()
print("Median before:", median_before)
# Out:
# Median before: 252.0

# %%
# Q6 ii)mode value
ost_frequent = df["horsepower"].mode()[0]
print("Most frequent value:", most_frequent)
# Out:
# Most frequent value: 252.0

# %%
# Q6  iii)using the fillna method to fill with the most frequent value
df["horsepower"] = df["horsepower"].fillna(most_frequent)

# %%
# Q6 iv)
median_after = df["horsepower"].median()
print("Median after:", median_after)
# NO
# Out:
# Median after: 252.0

# %%
# Q7
import numpy as np
# 1-2. Asia cars, selected columns
asia_cars = df[df["origin"] == "Asia"]
selected_columns = asia_cars[["vehicle_weight", "model_year"]]

# 3. First 7 rows
first_7_values = selected_columns.head(7)

# 4. Underlying NumPy array
X = first_7_values.to_numpy()

# 5. XTX = X.T @ X
XTX = X.T @ X

# 6. Invert XTX
XTX_inv = np.linalg.inv(XTX)

# 7. y array
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

# 8. w = XTX_inv @ X.T @ y
w = XTX_inv @ X.T @ y

# 9. Sum of w
w.sum().item()
# Out:
# 0.36919696904925486
